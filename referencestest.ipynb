# %% [markdown]
# hello [1]
#
# also also [2]

# %% [markdown]
# ## References
#
# [1] Gomes, Niladri and Mukherjee, Anirban and Zhang, Feng and Iadecola, Thomas and Wang, Cai-Zhuang and Ho, Kai-Ming and Orth, Peter P and Yao, Yong-Xin (2021). *Adaptive variational quantum imaginary time evolution approach for ground state preparation*. Advanced Quantum Technologies.
#
# [2] Ikeda, Tatsuhiko N and Abrar, Asir and Chuang, Isaac L and Sugiura, Sho (2023). *Minimum Trotterization formulas for a time-dependent Hamiltonian*. Quantum.
