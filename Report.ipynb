# %% [markdown]
# # Quantum Computing Group Project Report
# # Time Evolution
# ### Hugo, Kyran, Lara, Shae, Tamara
#
# # 1. Introduction

# %% [markdown]
# This project investigates how one can simulate the time evolution of the XXZ Heisenberg Hamiltonian. The interactions between these qubits is given by the bwlow hamiltonian H.
#
# $$H = -\sum_{i=1}^{L-1} \left( X_i \otimes X_{i+1} + Y_i \otimes Y_{i+1} + J_z Z_i \otimes Z_{i+1} \right)$$
#
# To cover different magnetisation of the states we consider two difrerent cases:
# - $J_z > 1$: ferromagnetic, initial states $|0\rangle^{\otimes L}$ or $|1\rangle^{\otimes L}$
# - $J_z < -1$: antiferromagnetic, initial state $|10\rangle^{\otimes L/2}$
#
# To make a spin wave excitation we apply $R_y(\pi/2)$ to the middle lattice site, rotating that spin into the $x$-$y$ plane. We then track the expectation values $\langle X_i(t)\rangle$, $\langle Y_i(t)\rangle$, $\langle Z_i(t)\rangle$ on each qubit over time.
#
# Our simulations were used to verify the evolution methods used, compare noise effects, and compare data to IBMs quantum computer. The picked time was $5 eV_1$ so that this would not take uo too much computational cost when run on IBMs quantum computer.

# %%
import numpy as np
import matplotlib.pyplot as plt
import functools as ft
import scipy as sp

import qiskit
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp, Statevector, Operator, Pauli
from qiskit.circuit.library import PauliEvolutionGate
from qiskit.synthesis import SuzukiTrotter
from qiskit.primitives import StatevectorEstimator
from scipy.optimize import minimize
from qiskit.visualization import plot_histogram
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error
from qiskit import transpile

# %% [markdown]
# ### 1.1 Building the Hamiltonian
#
# The given hamiltonian below measures interactions bwteeen neighbouring qubits, with a constant on the Z components to keep spin symentry.
#
# $$H = -\sum_{i=1}^{L-1} \left( X_i X_{i+1} + Y_i Y_{i+1} + J_z Z_i Z_{i+1} \right)$$
#
# This was built using qiskits operators below.

# %%
def hamiltonian1(L, Jz):
    """
    Docstring for hamiltonian
    
    :param X: X pauli op
    (X, 0, t)
    :param Y: Y pauli op
    :param Z: Z pauli op
    """
    ham_list = []

    for i in range (int(L)-1):
        ham_list.append(("XX", [i, i+1], -1)) # XX bc Xi and X i+1
        ham_list.append(("YY", [i, i+1], -1))
        ham_list.append(("ZZ", [i, i+1], -Jz))

    H =  SparsePauliOp.from_sparse_list(ham_list, num_qubits=L)

    return H

# %% [markdown]
# The value of $J_z$ decides the initial state of the quantum system under this given hamiltonian. A function was then made to pick the correct state and subsequent rotation for our initial states.

# %%
def initialise(Jz, L, allzeros, rotate_middle=True):
    """
    Return the initial Statevector for the given Jz regime.

    :param Jz: (float) anisotropy; must satisfy |Jz| > 1
    :param L:  (int) number of qubits
    :param allzeros: (bool)  for Jz > 1: True → |000…⟩, False → |111…⟩
    :param rotate_middle:(bool) if True, apply Ry(π/2) to qubit L//2
    :returns:            Statevector of the initial state
    """
    if Jz > 1:
        if allzeros:
            sv = Statevector.from_label("0" * L)
        else:
            sv = Statevector.from_label("1" * L)
    elif Jz < -1:
        alternating = "".join(["10"[i % 2] for i in range(L)])
        sv = Statevector.from_label(alternating)
    else:
        raise ValueError("Jz must be > 1 or < -1")

    #rotation is done at this atge bc trotter method can work with it out this function but mchlachan cannot
    if rotate_middle:
        middle = L // 2
        qc_rot = QuantumCircuit(L)
        qc_rot.ry(np.pi / 2, middle)
        sv = sv.evolve(Operator(qc_rot))   

    return sv

# %% [markdown]
# The hamiltonian time evolves these initial states by rotating the qubits and changing their state values. Below is an example of the first few time evolitions of the circuit starting with four qubits under this hamiltonian when the $Jz$ value was chosen to be above 1.

# %%
L=4
Jz=1.1
hamiltonian = hamiltonian1(L,Jz)
dt = 0.5 * 1e-2
gate = PauliEvolutionGate(operator=hamiltonian,time=dt)

st = SuzukiTrotter(order=1, reps=1)   #whats the advantage of doing reps here vs. appending on then measuring? I guess can only measure every reps?
# in real life, fix circuit depth/trotter circuit, then change dt to get data for different times
circ = st.synthesize(gate)

circ.decompose().draw("mpl")

# %% [markdown]
# When we display our data from simulations of this hamiltonian evolution of the qubits, we will use define pauli operators and observables to store the data.

# %%
pauli_x  = np.array([[0,  1 ], [1,   0]], dtype=complex)
pauli_y  = np.array([[0, -1j], [1j,  0]], dtype=complex)
pauli_z  = np.array([[1,  0 ], [0,  -1]], dtype=complex)
identity = np.eye(2, dtype=complex)

def observable_matrix(L, qubit, pauli):
    """Full 2^L × 2^L matrix for a single-site Pauli operator."""
    ops = [identity] * L
    ops[qubit] = pauli
    return ft.reduce(np.kron, ops)

def expectation_value(psi, obs):
    return np.real(np.vdot(psi, obs @ psi))

# %% [markdown]
# ## 2 Classical code
#
# The time evolution of a given system is given by
# $$|\psi(t)\rangle=U(t)|\psi(0)\rangle$$
# $$U(t)=\exp(-iHt)$$
#
# the function `hamiltonian1` gives us this hamiltonian.
#
# Classical simulations of this were used as a benchmark comparison for our quantum simulations data. This is donr by taking the matricies of the operation in the above circuit of the time evoliton and evolving them over time.

# %%
def ClassicalComparison(L, Jz, qubit_measured, direction_measured, steps=100, t_tot=1, allzeros=True):
    '''
    performs an expectation value measurement for a spin proj. in a certain direction on a certain qubit. Does this classically with matrix multiplication.
    (still need to make the initial state rotation classical) (rn, importing Hamiltonian.py as hm) (imports needed: scipy as sp, numpy as np, functools as ft)
    
    returns two np.arrays: ([time_values],[measurements])

    :param L: (int) number of qubits
    :param Jz: (float) J_z value 
    :param qubit_measured: (int) which qubit (1 to L) is measured
    :param direction_measured: (str) "X" "Y" or "Z", which projection operator is applied to the measured qubit
    :param steps: (int) number of time steps (auto set to 100)
    :param t_tot: (float) total time (in seconds? not seconds cause there are no hbars or cs) (auto set to 1)
    :param allzeros: (bool) if Jz>1, True chooses the all |0> state, False chooses the all |1> state
    '''

    #Hamiltonian as an np.array matrix
    matrix_h = np.array(hamiltonian1(L, Jz))

    #getting initial state, according to Jz value
    psi0 = np.array(initialise(Jz, L, allzeros, rotate_middle=True))

    #choosing correct pauli matrix
    pauli_map = {"x": pauli_x, "y": pauli_y, "z": pauli_z}
    pauli = pauli_map.get(direction_measured.lower())
    if pauli is None:
        raise ValueError("Please choose strings 'X', 'Y', or 'Z' for direction_measured")

    #creating our observable operator matrix, for our expectation value
    product = [np.eye(2) for i in range(L)]
    product[qubit_measured-1] = pauli         #list of matrices to kronecker product to build the observable matrix
    observable_m = ft.reduce(np.kron, product) #does multiple kronecker products in a row (with matrices in list)

    # Initialise an empty list to store the observables we compute
    measurements = []

    #timestep
    dt = t_tot / steps

    # Run a loop over timesteps
    for t in range(steps):
        Ut = sp.linalg.expm(-1j * matrix_h * dt * t)
        psi_t = Ut @ psi0
        expval = psi_t.conj().T @ observable_m @ psi_t
        measurements += [expval.real]

    t_values = np.array([dt * t for t in range(steps)])

    return (t_values, np.array(measurements))

# %% [markdown]
# ### 2.1 Results Classical for $J_z > 1$ ($J_z = 1.1$)
#
# $\ket{0000}$ case:

# %%
L, allzeros, Jz, steps, t_tot = 4, True, 1.1, 500, 5 #initial conditions

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q in range(1, L+1):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot, allzeros)
        ax.plot(t, vals, '.-', label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# $\ket{1111}$ case:

# %%
L, allzeros, Jz, steps, t_tot = 4, False, 1.1, 500, 5 #initial conditions
#allzeros = False sets to 1111 case

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q in range(1, L+1):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot, allzeros)
        ax.plot(t, vals, '.-', label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The main differences in the expectation values for each of the the initial states can be seen in the Z expectation values where the $\ket{0000}$ case fluctuates around the $+1$ value and the $\ket{1111}$ fluctuates about $-1$. These Z expectation values also differ from the X and Y ones in each $J_z$ value due to the anisotropy term $J_z$ which makes the coupling terms stronger in the Z expectations. This anisotropy $J_z$​ breaks the full SU(2) spin symmetry down to U(1) to make the model solvable using numerical models like the Suzuki-Trotter or McLachan methods.
#
# Furthermore, in all directions, the inner qubits experience more of this coupling and the outer $q_0$ and $q_3$ feel half the total coupling strength so behave more weakly.

# %% [markdown]
# ## 2.2 Classical results $J_z < -1$ ($J_z = -1.1$)

# %%
L, Jz, steps, t_tot = 4, -1.1, 500, 5

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q in range(1, L+1):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot)
        ax.plot(t, vals, '.-', label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# In the $J_z < -1 $ case the initial state of the qubits is $\ket{1010}$ so the Z expectation now fluccuates between $+1$ and $-1$. The Y and X expectations do fairly similar interactions as the $J_z > 1 $ but are a mixture of the two graphs due to stating qubits in alternating states.

# %% [markdown]
# # 3. Our built Suzuki-Trotter function
#
# The Suzuki-Trotter decomposition approximates the time evolution operator by splitting the Hamiltonian into individually exponentiable terms:
#
# $$U(t) = e^{-iHt} \approx \left(\prod_k e^{-i h_k \Delta t}\right)^n + \mathcal{O}(\Delta t^2)$$
#
# where $H = \sum_k h_k$ and $\Delta t = t/n$. Each $e^{-ih_k \Delta t}$ is a simple rotation gate directly implementable on quantum hardware.
#
# Trotterisation maps naturally onto quantum circuits with fixed, shallow depth per step. For comparison to IBM hardware the circuit depth must remain fixed and we therefor fix the Trotter circuit structure (controlled by `reps`), and vary $\Delta t$ to sample different times. This keeps the circuit depth constant and matches how the IBM jobs are actually submitted.
#
# The error in the approximation decreases as $\Delta t \to 0$ (more Trotter steps), but on hardware, smaller $\Delta t$ means more repetitions and deeper circuits. This makes the Suzuki-Trotter method a good model for hardware in quantum computation for small intervals of time.

# %%
def trotter_step_1st_order(circuit, H, dt):
    """
    Apply a single 1st-order Trotter step to a QuantumCircuit.

    :param circuit: QuantumCircuit to append gates to
    :param H:       SparsePauliOp Hamiltonian
    :param dt:      timestep size
    :returns:       updated circuit
    """
    for pauli_str, coeff in H.to_list():
        pauli_op = Pauli(pauli_str)
        gate = PauliEvolutionGate(pauli_op, time=dt * coeff.real)
        circuit.append(gate, range(circuit.num_qubits))
    return circuit

def first_order_trotter(H, t, n_steps, num_qubits=None):
    """
    Build a circuit implementing first-order Trotterised time evolution.

    :param H:          SparsePauliOp Hamiltonian
    :param t:          total evolution time
    :param n_steps:    number of Trotter steps
    :param num_qubits: system size (inferred from H if None)
    :returns:          QuantumCircuit
    """
    if num_qubits is None:
        num_qubits = H.num_qubits
    qc = QuantumCircuit(num_qubits)
    dt = t / n_steps
    for _ in range(n_steps):
        trotter_step_1st_order(qc, H, dt)
    return qc

# %% [markdown]
# ## 3.1 data from our trotter

# %%
from IPython.display import Image, display
display(Image(filename='trotter_all_xyz_separate.png'))

# %%
display(Image(filename='trotter_vs_exact_xyz.png'))

# %% [markdown]
# # Yap about this ^

# %% [markdown]
# ## 3.2 Our trotter with noise
#
# Quantum computers are extremely niosy devices so these values would not be close to expected data from real devices. We can artificially add noise to the system to make up for this diffrence.
#
# Many types of noise contribute to the overall system noise with extranal intereference, qubit flips and decoheremce and more, These error rates lie betwwen 0.01 and 0.0001 so rates within this range have been investigated.

# %% [markdown]
# The below code for noise model take ten minuites to run and so the code to run and print has been commented out. Images have been inserted of the results.

# %%
def trotter_with_noise(L, Jz, steps, t_tot, error_rate=0.0001, allzeros=True):
        H  = hamiltonian1(L, Jz)
        dt = t_tot / steps

        noise_model = NoiseModel()
        error_2q    = depolarizing_error(error_rate, 2)
        noise_model.add_all_qubit_quantum_error(error_2q, ['cx'])

        psi0 = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
        simulator = AerSimulator(method='statevector', noise_model=noise_model)
        states    = [np.array(psi0)]
        current_sv = np.array(psi0)

        # Build and transpile a single Trotter step once
        qc_step = QuantumCircuit(L)
        trotter_step_1st_order(qc_step, H, dt)
        qc_step = transpile(qc_step, simulator)
        print(qc_step.count_ops())

        for _ in range(steps):
            qc_run = QuantumCircuit(L)
            qc_run.set_statevector(current_sv)  # no import needed, method on QuantumCircuit
            qc_run = qc_run.compose(qc_step)
            qc_run.save_statevector()
            result = simulator.run(qc_run).result()
            current_sv = np.array(result.get_statevector())
            states.append(current_sv)

        return states

#L, Jz, steps, t_tot = 4, -1.1, 300, 5.0
#noisy_states = trotter_with_noise(L, Jz, steps, t_tot, error_rate=0.0001)
#t_values     = np.arange(len(noisy_states)) * (t_tot / steps)

#for rate in [0.0001, 0.001, 0.005, 0.01]:
    #noisy_states = trotter_with_noise(L, Jz, steps, t_tot, error_rate=rate)
    #fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    #for ax, pauli_mat, label in zip(axes, [pauli_x, pauli_y, pauli_z], ['X','Y','Z']):
        #for q in range(L):
            #obs  = observable_matrix(L, q, pauli_mat)
            #vals = [expectation_value(psi, obs) for psi in noisy_states]
            #ax.plot(t_values, vals, label=f'qubit {q}')
        #ax.set_title(rf'$\langle {label} \rangle$ — Trotter + Noise')
        #ax.set_xlabel(r'$t$')
        #ax.set_ylim(-1, 1)
        #ax.legend()
    #plt.tight_layout()
    #plt.show()

# %% [markdown]
# ### Error = 0.0001

# %%
display(Image(filename='ours_noise_0_0001.png'))
# Out:
# Error = 0.0001

# %% [markdown]
# ### Error = 0.001

# %%
display(Image(filename='ours_noise_0_001.png'))

# %% [markdown]
# ### Error = 0.005

# %%
display(Image(filename='ours_noise_0_005.png'))
# Out:
# Error = 0.001

# %% [markdown]
# ### Error = 0.01

# %%
display(Image(filename='ours_noise_0_01.png'))

# %% [markdown]
# The data shows that as the error rates increase to match more realistic hardware conditions, the values deviate further from the expeceted values simulated with the classical model. This is expected since noise interefres with qubits and the system itself and chnages the propogation of a state under a given hamiltonian.

# %% [markdown]
# ## 4. McLachlan Variational Time Evolution
#
# The state is restricted to a parametrised ansatz $|\psi(\theta)\rangle$.
# McLachlan's variational principle gives:
#
# $$M\dot{\theta} = V$$
#
# $$M_{ij} = \mathrm{Re}\langle \partial_i \psi | \partial_j \psi \rangle, \qquad V_i = \mathrm{Im}\langle \partial_i \psi | H | \psi \rangle$$
#
# We numerically differentiate:
# $$\partial_i \psi \approx \frac{|\psi(\theta + \epsilon e_i)\rangle - |\psi(\theta - \epsilon e_i)\rangle}{2\epsilon}$$

# %%
n_layers = 4   # depth of ansatz — increase if evolution looks stuck

def ansatz_circuit(theta, L):
    """
    Ansatz: n_layers of (Ry, Rz, Rx) on each qubit followed by a CNOT chain.
    len(theta) must equal 3 * L * n_layers.
    """
    qc = QuantumCircuit(L)
    k  = 0
    for _ in range(n_layers):
        for q in range(L):
            qc.ry(theta[k], q); k += 1
            qc.rx(theta[k], q); k += 1
            qc.rz(theta[k], q); k += 1
        for q in range(L - 1):
            qc.cx(q, q + 1)
    return qc

def psi_theta(theta, L):
    return Statevector(ansatz_circuit(theta, L)).data

def psi_derivative(theta, i, L, eps=1e-6):
    tp = theta.copy(); tp[i] += eps
    tm = theta.copy(); tm[i] -= eps
    return (psi_theta(tp, L) - psi_theta(tm, L)) / (2 * eps)

def build_M(theta, L):
    n      = len(theta)
    derivs = [psi_derivative(theta, i, L) for i in range(n)]
    M      = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            M[i, j] = np.real(np.vdot(derivs[i], derivs[j]))
    return M

def build_V(theta, H, L):
    psi  = psi_theta(theta, L)
    Hpsi = H @ psi
    n    = len(theta)
    V    = np.zeros(n)
    for i in range(n):
        V[i] = np.imag(np.vdot(psi_derivative(theta, i, L), Hpsi))
    return V

def fit_theta_to_state(psi_target, L, n_params, n_restarts=10):
    """
    Find theta minimising 1 - |⟨psi_target|psi(theta)⟩|².
    Uses multiple random restarts to avoid local minima.
    """
    best_theta, best_loss = None, np.inf

    def loss(theta):
        return 1.0 - abs(np.vdot(psi_target, psi_theta(theta, L))) ** 2

    for _ in range(n_restarts):
        t0  = np.random.uniform(-np.pi, np.pi, n_params)
        res = minimize(loss, t0, method="L-BFGS-B")
        if res.fun < best_loss:
            best_loss, best_theta = res.fun, res.x

    print(f"Fit overlap loss: {best_loss:.6f}  (0 = perfect)")
    return best_theta

def mclachlan_evolve(theta0, H, L, dt, steps):
    theta  = theta0.copy()
    states = [psi_theta(theta, L)]
    reg    = 1e-8
    for step in range(steps):
        M         = build_M(theta, L)
        V         = build_V(theta, H, L)
        theta_dot = np.linalg.solve(M + reg * np.eye(len(theta)), V)
        theta    += dt * theta_dot
        states.append(psi_theta(theta, L))
        if (step + 1) % 50 == 0:
            print(f"  step {step+1}/{steps}")
    return states

# %% [markdown]
# ## 4.1 Our McLachan data
#
# The below code for noise model take ten minuites to run and so has beemn left in a commented out. Images have been inserted of the results.

# %%
L       = 4
Jz      = -1.1
steps   = 300
t_total = 5.0
dt      = t_total / steps
allzeros = True

#psi_target = np.array(initialise(Jz, L, allzeros, rotate_middle=True))
#H_mat      = hamiltonian1(L, Jz).to_matrix()

#n_params = 3 * L * n_layers
#theta0   = fit_theta_to_state(psi_target, L, n_params, n_restarts=10)

#z_obs = observable_matrix(L, L//2, pauli_z)
#print(f"⟨Z⟩ middle qubit at t=0: {expectation_value(psi_target, z_obs):.4f}  (expect ~0)")

#print("Running McLachlan evolution...")
#mc_states = mclachlan_evolve(theta0, H_mat, L, dt, steps)
#t_values  = np.arange(len(mc_states)) * dt

#fig, axes = plt.subplots(1, 3, figsize=(18, 5))
#for ax, pauli_mat, label in zip(axes, [pauli_x, pauli_y, pauli_z], ['X','Y','Z']):
    #for q in range(L):
        #obs  = observable_matrix(L, q, pauli_mat)
        #vals = [expectation_value(psi, obs) for psi in mc_states]
        #ax.plot(t_values, vals, '.-', label=rf'$q_{q}$')
    #ax.set_title(rf'$\langle {label} \rangle$ over time — McLachlan')
    #ax.set_xlabel(r'$t$')
    #ax.set_ylim(-1, 1)
    #ax.legend()
#plt.tight_layout()
#plt.show()

# %%
display(Image(filename='mclachan_ours_results.png'))

# %% [markdown]
# This data is less stable than the data taken from our trotter system. A way to increas the accuracy of this would be to inrease the number of layers, but the runtime of these would also massivley increase so the Trotter method is a valid method to use instead.

# %% [markdown]
# ## 5. Qiskit inbuilt trotter analysis
#
# This does the same as our trotter but with a function in qiskit, this data will be the best to fit to IBMs quantum computer data.

# %%
def TheoreticalST(L, Jz, qubit_measured, direction_measured,
                  steps, t_tot, allzeros, order=1, reps=1):
    """
    Qiskit Suzuki–Trotter: growing circuit (theoretical, not hardware-compatible).
    Appends one ST timestep circuit `steps` times to build up the full evolution.

    :param L:                  (int)   number of qubits
    :param Jz:                 (float) anisotropy parameter
    :param qubit_measured:     (int)   qubit index (1-based)
    :param direction_measured: (str)   'X', 'Y', or 'Z'
    :param steps:              (int)   number of time steps
    :param t_tot:              (float) total evolution time
    :param order:              (int)   Suzuki–Trotter order (default 1)
    :param reps:               (int)   ST repetitions per appended step (default 1)
    :param allzeros:           (bool)  for Jz>1: True→|000…⟩
    :returns: (t_values, measurements) as np.arrays
    """
    hamiltonian = hamiltonian1(L, Jz)
    dt   = t_tot / steps
    gate = PauliEvolutionGate(operator=hamiltonian, time=dt)
    st   = SuzukiTrotter(order=order, reps=reps)
    circ = st.synthesize(gate)

    paulistring = "".join(
        direction_measured if i == qubit_measured - 1 else "I" for i in range(L)
    )
    obs       = SparsePauliOp([paulistring], coeffs=[1])
    estimator = StatevectorEstimator()

    psi0 = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    qc   = QuantumCircuit(L)
    qc.initialize(psi0.data)

    measurements = []
    for _ in range(steps):
        qc.append(circ, range(L))
        result = estimator.run(pubs=[(qc, [obs])]).result()
        measurements.append(result[0].data.evs[0])

    t_values = np.array([dt * t for t in range(steps)])
    return t_values, np.array(measurements)


def PhysicalST(L, Jz, qubit_measured, direction_measured,
               steps, t_tot, allzeros, order=1, reps=5):
    """
    Qiskit Suzuki–Trotter: fixed-depth circuit (hardware-compatible).
    Rebuilds a fresh circuit for each time point, keeping circuit depth constant.
    This is the method submitted to IBM quantum hardware.

    :param L:                  (int)   number of qubits
    :param Jz:                 (float) anisotropy parameter
    :param qubit_measured:     (int)   qubit index (1-based)
    :param direction_measured: (str)   'X', 'Y', or 'Z'
    :param steps:              (int)   number of time points sampled
    :param t_tot:              (float) total evolution time
    :param order:              (int)   Suzuki–Trotter order (default 1)
    :param reps:               (int)   fixed circuit depth in Trotter steps (default 5)
    :param allzeros:           (bool)  for Jz>1: True→|000…⟩
    :returns: (t_values, measurements) as np.arrays
    """
    hamiltonian = hamiltonian1(L, Jz)
    st = SuzukiTrotter(order=order, reps=reps)

    paulistring = "".join(
        direction_measured if i == qubit_measured - 1 else "I" for i in range(L)
    )
    obs       = SparsePauliOp([paulistring], coeffs=[1])
    estimator = StatevectorEstimator()   # replace with IBM Estimator to run on hardware

    psi0    = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    dt      = t_tot / steps
    t_values = np.array([dt * t for t in range(steps)])

    measurements = []
    for timeval in t_values:
        gate = PauliEvolutionGate(operator=hamiltonian, time=timeval)
        circ = st.synthesize(gate)
        qc   = QuantumCircuit(L)
        qc.initialize(psi0.data)
        qc.append(circ, range(L))
        result = estimator.run(pubs=[(qc, [obs])]).result()
        measurements.append(result[0].data.evs[0])

    return t_values, np.array(measurements)

# %%
# --- 5.1 TheoreticalST vs Exact (benchmark, not hardware-compatible): Jz = 1.1 ---
# Shows that the Qiskit built-in Trotter matches exact when circuit depth grows freely
L, Jz, steps, t_tot = 4, 1.1, 150, 5

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q in range(1, L + 1):
        t_ex, ex   = ClassicalComparison(L, Jz, q, direction, steps, t_tot)
        t_th, th_  = TheoreticalST(L, Jz, q, direction, steps, t_tot, allzeros, order=1, reps=1)
        ax.plot(t_ex, ex,       label=rf'Exact $\langle {label}_{q}\rangle$')
        ax.plot(t_th, th_, '--', label=rf'TheoreticalST $\langle {label}_{q}\rangle$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'TheoreticalST vs Exact: $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend(fontsize=7)
plt.tight_layout()
plt.show()

# %%
# --- 5.1 PhysicalST vs Exact: Jz = 1.1 ---
L, Jz, steps, t_tot, reps = 4, 1.1, 150, 5, 50

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q in range(1, L + 1):
        t_ex, ex   = ClassicalComparison(L, Jz, q, direction, steps, t_tot)
        t_st, st_  = PhysicalST(L, Jz, q, direction, steps, t_tot, allzeros, order=2, reps=reps)
        ax.plot(t_ex, ex,       label=rf'Exact $\langle {label}_{q}\rangle$')
        ax.plot(t_st, st_, '--', label=rf'PhysicalST $\langle {label}_{q}\rangle$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'PhysicalST vs Exact: $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend(fontsize=7)
plt.tight_layout()
plt.show()

# %% [markdown]
# yap about it

# %%
#need noise for this trotter qiskit thing

# %% [markdown]
# noise- same as noise on our model but this is what we will compare to the IBM data

# %% [markdown]
# # 6. IMB quantum computer data
#
# add yap

# %%
# add images of plots from ibm and photos of code ig
display(Image(filename='name_of_file')) #make sure file is uploaded to main branch of github

# %% [markdown]
# Conclusion
#
# Time limit, no higher order trotters considered bc of imb time limit, so data would not be comparable to a real quatum computer.
