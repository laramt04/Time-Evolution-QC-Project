# %% [markdown]
# # Quantum Computing Group Project Report
# # Time Evolution
# ### Lara Moyana-Taylor, Kyran Klazek-Schryer, Hugo Leigh-Watts, Tamara El-Sakkout, and Shae Swerdfeger
#
# **TODO: Contents or oveview/abstract paragraph? can help with organizing and so reader doesnt feel lost/aimless first readthrough**
#
# ## 1. Introduction

# %% [markdown]
# Quantum computers are able to use the principles of quantum mechanics directly in their calculations, unlike conventional computers which fail to do so. Thanks to this, they have proven to be increasingly useful to study quantum many-body systems, such as interacting spins[1]. We are going to study and use the XXZ Heisenberg model, a model often used in condensed matter physics to describe the time evolution of a chain of spins and understand the interactions between them.
#
# The aim of the project is to compare three methods allowing us to see the difference between classical and quantum algorithms: exact simulations on a classical computer, the Suzuki-Trotter method and the McLachlan variation method. We will simulate quantum dynamics by performing time evolution of the XXZ Heisenberg Hamiltonian below:
#
#
#
# $$H = -\sum_{i=0}^{L-2} \left( X_i \otimes X_{i+1} + Y_i \otimes Y_{i+1} + J_z Z_i \otimes Z_{i+1} \right)$$
#
#
# where $X_i$, $Y_i$ and $Z_i$ are the Pauli matrices acting on site i, in the respective directions x, y and z. The coefficient $J_z$ is the anisotropy coupling term[2] describing the strength of the ZZ interaction compared to the other two terms, XX and YY, whose coupling constants are equal in the XXZ model. Here, $J_z$ controls the phase of the system.
#
#
# To cover different magnetisation of the states we consider two different cases:
# - $J_z > 1$: ferromagnetic regime, aligned spins initial states $|0\rangle^{\otimes L}$ or $|1\rangle^{\otimes L}$
# - $J_z < -1$: antiferromagnetic regime, alternating spins initial state $|10\rangle^{\otimes L/2}$
#
# To make a spin wave excitation we apply a rotation $R_y(\pi/2)$ to the middle lattice site[3], rotating that spin into the $x$-$y$ plane. This creates a local perturbation in the spin configuration whose evolution we will observe as it propagates through the system under Hamiltonian dynamics. To do so, we then track the expectation values $\langle X_i(t)\rangle$, $\langle Y_i(t)\rangle$, $\langle Z_i(t)\rangle$ on each qubit over time.
#
# In this report, we first construct the XXZ Hamiltonian and initialise the relevant states. Then, we compute the exact time evolution with classical computer simulations. Next, we study Suzuki-Trotter evolution manually and using the Qiskit function, comparing both methods. We also analyse noise effects and compare with the McLachlan variational evolutional method. Finally we assess how the different models work and compare to a real quantum computer.
#
#
# Our simulations were used to verify the evolution methods used, compare noise effects, and compare data to IBMs quantum computer. The picked time was $5 (eV)^{-1}$ (in natural units where $\hbar=1$ time is measured in inverse energy units) so that this would not take up too much computational cost when run on IBMs quantum computer.
#
# It is important to note that, in this project, we are only studying small system sizes, for which we can expect simulations on classical computers to be efficient and provide exact results. However, simulating the time evolution of many-body systems is computationally difficult on these computers as the size of the space grows exponentially with the number of spins. Therefore, quantum computers are expected to simulate large scaled systems more efficiently than classical ones, by directly using quantum properties and implementing unnitary evolution. The main issue with quantum computers is the noise which can affect our results[4]. Thus we will also simulate noise and study different cases to interpret this.

# %%
import numpy as np
import matplotlib.pyplot as plt
import functools as ft
import scipy as sp

import qiskit
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp, Statevector, Operator, Pauli
from qiskit.circuit.library import PauliEvolutionGate
from qiskit.synthesis import SuzukiTrotter
from qiskit.primitives import StatevectorEstimator
from scipy.optimize import minimize
from qiskit.visualization import plot_histogram
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error
from qiskit import transpile
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, Session

from IPython.display import Image, display

# %% [markdown]
# ## 1.1 Building the Hamiltonian
#
# As explained previsously, the given Hamiltonian below measures interactions between neighbouring qubits, with the anisotropy constant $J_z$ in the ZZ term describing spin symmetry.
#
# $$H = -\sum_{i=1}^{L-1} \left( X_i X_{i+1} + Y_i Y_{i+1} + J_z Z_i Z_{i+1} \right)$$
#
# The first step is thus to construct the Hamiltonian, H, using Qiskit operators, as shown below.

# %%
def hamiltonian1(L, Jz):
    """
    Docstring for hamiltonian
    
    :param X: X pauli op
    (X, 0, t)
    :param Y: Y pauli op
    :param Z: Z pauli op
    """
    ham_list = []

    for i in range (int(L)-1):
        ham_list.append(("XX", [i, i+1], -1)) # XX bc Xi and X i+1
        ham_list.append(("YY", [i, i+1], -1))
        ham_list.append(("ZZ", [i, i+1], -Jz))

    H =  SparsePauliOp.from_sparse_list(ham_list, num_qubits=L)

    return H

# %% [markdown]
# The value of $J_z$ controls the symmetry of the model[4] : when $J_z = 1$, the system has full spin rotational symmetry while for $J_z \neq 1$ this symmetry is broken, leading to anisotropic spin interactions. In this project, we focus on the latter case, particularly the when $J_z < -1$ and $J_z > 1$, corresponding to different initial states. A function is therefore made to pick the correct initial state for a given $J_z$ and apply the appropriate rotation.

# %%
def initialise(Jz, L, allzeros, rotate_middle=True):
    """
    Return the initial Statevector for the given Jz regime.

    :param Jz: (float) anisotropy; must satisfy |Jz| > 1
    :param L:  (int) number of qubits
    :param allzeros: (bool)  for Jz > 1: True → |000…⟩, False → |111…⟩
    :param rotate_middle:(bool) if True, apply Ry(π/2) to qubit L//2
    :returns:            Statevector of the initial state
    """
    if Jz > 1:
        if allzeros:
            sv = Statevector.from_label("0" * L)
        else:
            sv = Statevector.from_label("1" * L)
    elif Jz < -1:
        alternating = "".join(["10"[i % 2] for i in range(L)])
        sv = Statevector.from_label(alternating)
    else:
        raise ValueError("Jz must be > 1 or < -1")

    #rotation is done at this stage bc trotter method can work with it out this function but mchlachan cannot
    if rotate_middle:
        middle = L // 2
        qc_rot = QuantumCircuit(L)
        qc_rot.ry(np.pi / 2, middle)
        sv = sv.evolve(Operator(qc_rot))   

    return sv

# %% [markdown]
# ZX calculus[5] lets us break down a simulation of a simple Hamiltonian into a series of Pauli operators (X, Y, Z) and Clifford gates (like H). This process leads to Trotterization, the implementation of the Suzuki-Trotter method, which we will investigate for the simulation of our Hamiltonian over time.
#
# This method consists in applying chosen quantum gates successively to approximate the time evolution of a complex quantum system. It decomposes the Hamiltonian into smaller quantum circuits that can be handled by a quantum computer.
#
# The Hamiltonian time evolves these initial states by rotating the qubits and changing their state values. Below is an example of the first few time evolutions of the circuit starting with four qubits under this Hamiltonian when the $J_z$ value was chosen to be above 1.
#
# The chosen values for the rest of the project were $1.1$ for our $J_z > 1$ and $-1.1$ for our $J_z < -1$ to prevent large oscillations and increase the numerical stability of our simulations by keeping $J_z$ fairly small[6].

# %%
L=5
Jz=1.1
hamiltonian = hamiltonian1(L,Jz)
dt = 0.5 * 1e-2
gate = PauliEvolutionGate(operator=hamiltonian,time=dt)

st1 = SuzukiTrotter(order=1, reps=1)   #all in line, growing circuit depth with # of qubits
st2 = SuzukiTrotter(order=1, reps=2)   #all in line, growing circuit depth with # of qubits
st_brickwork = SuzukiTrotter(order=1, reps=2, preserve_order=False) #more emulating brickwork, circuit depth constant with # of qubits

circ1 = st1.synthesize(gate)
circ2 = st2.synthesize(gate)
circ_brick = st_brickwork.synthesize(gate)

# %% [markdown]
# Below is a visualization of a Suzuki-Trotter circuit with two time repetitions `reps`, acting on 5 qubits. This circuit is plotted in terms of the X and Y rotation gates that evolve the states according to the Hamiltonian. A more thorough explanation of the approximation of the Suzuki-Trotter Method is given in section 3, where we have built our own implementation.

# %%
# Suzuki Trotter for 5 qubits, 2 reps, not optimizing with brickwork pattern
circ2.draw('mpl')

# %% [markdown]
# As the Suzuki-Trotter (S-T) reps above are simply appended on to the end of each previous timestep, the above circuit depth will increase slightly with the number of qubits. To counteract this, we can map out the circuit that performs the same time evolution, but with the more familiar 'brickwork' circuit pattern one might be used to. This is done below, via qiskit's built-in `SuzukiTrotter` implementation, with setting `preserve_order=False`. For the plot below, the circuit depth does not grow with the number of qubits (thanks to the 'brickwork' pattern), as seen in section 6 of this report. This brickwork implementation of S-T is the version of qiskit's `SuzukiTrotter` that we will use for the rest of the report.

# %%
# Suzuki Trotter for 5 qubits, 2 reps, optimizing for circuit depth, with preserve_order=False
# this is emulating the 'brickwork' pattern seen in lecture
circ_brick.draw('mpl')

# %% [markdown]
# In perhaps a more familiar visualization, below we have plotted the first Suzuki-Trotter[7] circuit shown, now decomposed into fundamental gates (CNOT, Hadamard, etc.). Decomposing the circuit this way, and investigating the number of CNOT gates in a row, is one way of calculating circuit depth in a way relevant to performing these calculations on a real quantum chip. This is explored further at the beginning of section 6. This visualization is also closer to what the chip "sees".

# %%
#The first circuit decomposed, but for just one ST rep, not brickwork, preserve_order=True
circ1.decompose().draw("mpl")

# %% [markdown]
# Finally, we have also plotted a transpiled version of this circuit, which is hardware specific. In this case, this is the transpilation of the brickwork Suzuki-Trotter circuit that gets sent to the `ibm_fez` chip[8], in terms of fundamental gates it can perform/understand. The numbers on the left are the qubits on which this code would run. Qiskit automatically chooses qubits close to eachother, which are performing well at that moment[9]. There would also be ancilla qubits involved in this setup, for error correction. These ancilla qubita are where we read the data from[10], as to not interefere with the unstable information in a qubit itself.

# %%
# transpiled circuit for a given chip, here we are using ibm_fez as an example
import json
from qiskit_ibm_runtime import QiskitRuntimeService, Session
try:
    with open('../apikey.json') as file:
        api_key = json.load(file)
except:
    print("No API key found: make sure to modify this code and enter your API key manually in the below command.")
QiskitRuntimeService.save_account(channel='ibm_quantum_platform', instance = 'open-instance', token=api_key["apikey"], overwrite=True, set_as_default=True)
service = QiskitRuntimeService()                    #load saved credentials for API key
real_backend = service.backend("ibm_fez")           #choosing the ibm fez chip as a specific example

qc_t = transpile(circ_brick,backend=real_backend,optimization_level=3) #transpiled circuit, for ibm_fez specifically, at optimization 3
qc_t.draw('mpl')
# Out:
# No API key found: make sure to modify this code and enter your API key manually in the below command.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       7 except:
#       8     print("No API key found: make sure to modify this code and enter your API key manually in the below command.")
# ----> 9 QiskitRuntimeService.save_account(channel='ibm_quantum_platform', instance = 'open-instance', token=api_key["apikey"], overwrite=True, set_as_default=True)
#      10 service = QiskitRuntimeService()                    #load saved credentials for API key
#      11 real_backend = service.backend("ibm_fez")           #choosing the ibm fez chip as a specific example
#
# NameError: name 'api_key' is not defined

# %% [markdown]
# **put what was written on top (about the qubits numbers etc) here so that it can be right under what we're talking about?**
#
# When we display our data from simulations of this hamiltonian evolution of the qubits, we will use define pauli operators and observables to store the data.

# %% [markdown]
# ## 2. "Classical" code
#
# To compare the quatum-simulated data to the true time evolution results, we can code in the mathematical time evolution of a quatum state, run in a "classical" way (with matrix multiplication, exponentiation, ect., run on a classical computer).
#
# The time evolution of a given system is given by
# $$|\psi(t)\rangle=U(t)|\psi(0)\rangle$$
# $$U(t)=\exp(-iHt)$$
#
# Where the $|\psi(0)\rangle$ is the orginal qubit state given by the `initialise` function, $H$ is the hamiltonian of the system given by the `hamiltonian1` function, and $|\psi(t)\rangle$ is the state of the qubits at time $t$. We are measuring the spin of specific qubits as they progress through time in this system.
#
# To compute an observable, the expectation value of this observable is then taken:
# $$\langle X_i(t)\rangle = \langle\psi(t)|X_i|\psi(t)\rangle$$
# where $X_i$ is the Pauli spin matrix observable for the $i$ th qubit, in the x direction.
#
# The expectations values $\langle X_i(t)\rangle$,  $\langle Y_i(t)\rangle$,  and $\langle Z_i(t)\rangle$ measure each qubit's spin orientation over time, thus corresponding to the propagation of the local excitation through the system.
#
# Calculations of this, done with classical computing methods, are used as a benchmark comparison for our quantum simulation data. By performing the above matrix calculations, with the initial state given by the circuit setup, and evolving them over time (through different values of $t$), we get an exact calculation of the behaviour of the system. The function `ClassicalComparison` performs this calculation.

# %%
def ClassicalComparison(L, Jz, qubit_measured, direction_measured, steps=100, t_tot=1, allzeros=True):
    '''
    performs an expectation value measurement for a spin proj. in a certain direction on a certain qubit. Does this classically with matrix multiplication.
    (still need to make the initial state rotation classical) (rn, importing Hamiltonian.py as hm) (imports needed: scipy as sp, numpy as np, functools as ft)
    
    returns two np.arrays: ([time_values],[measurements])

    :param L: (int) number of qubits
    :param Jz: (float) J_z value 
    :param qubit_measured: (int) which qubit (1 to L) is measured
    :param direction_measured: (str) "X" "Y" or "Z", which projection operator is applied to the measured qubit
    :param steps: (int) number of time steps (auto set to 100)
    :param t_tot: (float) total time (in seconds? not seconds cause there are no hbars or cs) (auto set to 1)
    :param allzeros: (bool) if Jz>1, True chooses the all |0> state, False chooses the all |1> state
    '''

    #Hamiltonian as an np.array matrix
    matrix_h = np.array(hamiltonian1(L, Jz))

    #getting initial state, according to Jz value
    psi0 = np.array(initialise(Jz, L, allzeros, rotate_middle=True))

    #choosing correct pauli matrix
    pauli_x  = np.array([[0,  1 ], [1,   0]], dtype=complex)
    pauli_y  = np.array([[0, -1j], [1j,  0]], dtype=complex)
    pauli_z  = np.array([[1,  0 ], [0,  -1]], dtype=complex)
    pauli_map = {"x": pauli_x, "y": pauli_y, "z": pauli_z}

    pauli = pauli_map.get(direction_measured.lower())
    if pauli is None:
        raise ValueError("Please choose strings 'X', 'Y', or 'Z' for direction_measured")

    #creating our observable operator matrix, for our expectation value
    product = [np.eye(2) for i in range(L)]
    product[qubit_measured-1] = pauli          #list of matrices to kronecker product to build the observable matrix
    observable_m = ft.reduce(np.kron, product) #does multiple kronecker products in a row (with matrices in list)

    # Initialise an empty list to store the observables we compute
    measurements = []

    #timestep
    dt = t_tot / steps

    # Run a loop over timesteps
    for t in range(steps):
        Ut = sp.linalg.expm(-1j * matrix_h * dt * t)
        psi_t = Ut @ psi0
        expval = psi_t.conj().T @ observable_m @ psi_t
        measurements += [expval.real]

    t_values = np.array([dt * t for t in range(steps)])

    return (t_values, np.array(measurements))

# %% [markdown]
# The following sections plot the 'classical' calculation of time evolution for five qubits, for different cases of the Hamiltonian described at the beginning of the report. Section 2.1 looks at the case where $J_z>1$, whereas section 2.2 looks at the case where $J_z<-1$.

# %% [markdown]
# ## 2.1. Results Classical for $J_z > 1$ ($J_z = 1.1$)
#
# We first study the case with five qubits ($L=5$) in the anisotropic ferromagnetic regime for $J_z > 1$, and set $J_z = 1.1$ close to 1 for reasons explained in Section 2.1.
#
# We measure the time evolution of the expectation values of the spin excitation in all three directions (x, y and z). As we are studying the case where we have created a local excitation by applying a rotation $R_y(\pi/2)$ to the middle lattice site, the spin is in the $x$-$y$ plane as this rotates the spin from the z-axis to the x-axis. Because of this, if applied to an even number of qubits, the oscillations of the different qubits will not be symmetric and we will obtain distinct expectation values for each qubit over time, whereas, for an uneven number of qubits, the rotation will happen such that there will be an equal number of qubits before and after the excitation, making the oscillations symmetric on either side of the middle qubit.
# To simplify results and interpretation, we decide to choose an uneven number of qubits, which should lead to $(L-1)/2+1$ distinct-looking expectation value time evolutions.
#
# We can expect the initial  $\langle Y_i(t=0)\rangle$ to be close to zero (it is unchanged) for all qubits, the X component to have a large expectation value $\langle X_i(t)\rangle$ (close to 1) for the qubit on which this rotation was applied and close to 0 for the others, and the Z component to be smaller than it's initial value of 1 or -1 (by definition of the expectation value and the Z Pauli matrix, depending on which intitial state), $\langle Z_i(t=0)\rangle \approx 0$ for this same qubit, and equal to its initial value for the rest[11].
#
# **needs to be written better whoops brain isn't working anymore**
#
# Under time evolution, the local excitation will propagate through the spin chain through close neighbour interactions, which will lead to oscillations of all expectation values. We expect  $\langle X_i(t)\rangle$ and  $\langle Y_i(t)\rangle$ to have similar oscillations but different ones to $\langle Z_i(t)\rangle$ due to the coupling constant  $J_z$ forcing it to stay close to the initial expectation value of 1 or -1, depending on the initial state.
# It is also important to note that we expect the sum of all expectation values to be 1 or -1 at all times, depending on the initial state, for the excited site, and 0 for all other qubits, as they physically have to be in these three directions.
#
#
#
# - $\ket{00000}$ case:
#
# The sum of all expectation values should be 1 for each qubit at every moment of time.

# %%
L, allzeros, Jz, steps, t_tot = 5, True, 1.1, 250, 5 #initial conditions

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q, lines in zip(range(1, L+1),['.-','.-','-','--','--']):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot, allzeros)
        ax.plot(t, vals,lines, label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(18, 5))
for ax, q, in zip(axes, [1,2,3,4,5]):
    for direction in ['X','Y','Z']:
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot, allzeros)
        ax.plot(t, vals, label=rf'$\langle {direction} \rangle$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle X(t) \rangle$, $\langle Y(t) \rangle$, $\langle Z(t) \rangle$')
    ax.set_title(rf'Time evolution of qubit {q}, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As expected, we can only observe 3 distinct expectation value time evolutions for all directions, as $q_0$ and $q_4$, as well as $q_1$ and $q_3$ are respectively superimposed. This symmetry is also shown below, where we have plotted the same thing but for each qubit seperately. Moreover, the initial values we had previously predicted are aligned with the theory : all but one equal to 0 for $\langle X_i(t)\rangle$, all equal to zero for $\langle Y_i(t)\rangle$, and all but one equal to 1 for $\langle Z_i(t)\rangle$. We can confirm the coherence of these graphs as the sum of all expectation values is equal to 1 for $q_2$ and 0 for all other $q_i$'s, at all times. Finally, the Z expectation values $\langle Z_i(t)\rangle$ do indeed oscillate close to 1 and never become negative, highlighting the importance of $J_z$, keeping the spins in the z direction close to the initial state due to strong interactions. We can notice that the middle qubit $q_2$ is the most affected by the rotation in all three directions and thus oscillates more than the others. In particular, $\langle Z_2(t)\rangle$ oscillates between 0 and 1, unlike the other qubits whose $\langle Z_i(t)\rangle$ stay above 0.5.
#
# **if you want to add anything else, please do. I couldn't think of anything**
# **might need to modify how it was said, not sure it's great**

# %% [markdown]
# - $\ket{11111}$ case:
#
# Here, we follow the same reasoning as previously, this time expecting the sum of all expectation values to be -1 for each qubit at every moment of time.

# %%
L, allzeros, Jz, steps, t_tot = 5, False, 1.1, 250, 5 #initial conditions
#allzeros = False sets to 1111 case

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q, lines in zip(range(1, L+1),['.-','.-','-','--','--']):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot, allzeros)
        ax.plot(t, vals, lines, label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We can once again validate our expectations here, for the same reasons as state $\ket{00000}$, and notice how $q_2$ acts differently, being the initially excited site.

# %% [markdown]
# **Kyran : discuss differences and similarities more, maybe explian/think about the why?**
#
# The main differences in the expectation values for each of the the initial states can be seen in the Z expectation values where the $\ket{0000}$ case fluctuates around the $+1$ value and the $\ket{1111}$ fluctuates about $-1$. The expectation values for $\langle X(t)\rangle$ and $\langle Z(t)\rangle$ are exactly opposite (flipped along the $y=0$ axis), while the $\langle Y(t)\rangle$ expectation values do not change. This can be visualized on the Bloch sphere, where the $z$-direction is flipped, and then our rotation of the middle qubit has the reflected effect, between $\ket{0000}$ and $\ket{1111}$. These Z expectation values also differ from the X and Y ones in each $J_z$ value due to the anisotropy term $J_z$ which makes the coupling terms stronger in the Z expectations. This anisotropy $J_z$​ breaks the full SU(2) spin symmetry down to U(1) to make the model solvable using numerical models like the Suzuki-Trotter or McLachan methods.
#
# Furthermore, in all directions, the inner qubits experience more of this coupling and the outer $q_0$ and $q_3$ feel half the total coupling strength so behave more weakly.
#
# **Tamara : I think I kind of explained the why but we didn't really say it the same way, I'll look at this again, maybe we should try to merge what we said, sorry hadn't seen this before I did it**

# %% [markdown]
# ## 2.2. Classical results $J_z < -1$ ($J_z = -1.1$)
#
#
#
# Now, we move onto the case with ($L=5$) qubits in the anisotropic antiferromagnetic regime for $J_z < -1$, and set $J_z = -1.1$ close to -1 for reasons explained in Section 2.1. Each qubit wants to align opposite to neighbous due to the sign of $J_z$ but is also being rotated and coupled via the XX and YY interactions. This creates a non-uniform initial state spin chain, leading to more complicated dynamics shown through more irregular oscillations.
#
# Once again, we measure the time evolution of the expectation values of the spin excitation in all three directions (x, y and z). Unlike the ferromagnetic case, the initial state is an alternating spin state and so we expect it to look like a superposition of the two previous cases. However, we still expect the oscillating behaviour of x and y to be similar, but different to the z component, which should now oscillate between 1 and -1 through neighbouring spin interactions.
#
# Because of this, the sum of all expectation values should now be equal to 0 at all times for an even number of qubits, and either 1 or -1 for an uneven number of qubits, depending on the orientation of the excited spin after the rotation.

# %%
L, Jz, steps, t_tot = 5, -1.1, 250, 5

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q, lines in zip(range(1, L+1),['.-','.-','-','--','--']):
        t, vals = ClassicalComparison(L, Jz, q, direction, steps, t_tot)
        ax.plot(t, vals, lines, label=rf'$q_{q-1}$')
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'Time evolution of $\langle {label} \rangle$, $J_z={Jz}$')
    ax.set_ylim([-1.1, 1.1])
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We can observe the less irregular oscillations here, as expected.
# In the $J_z < -1 $ case the initial state of the qubits is $\ket{10101}$ so the Z expectation now fluctuates between $+1$ and $-1$, as expected. The Y and X expectations do fairly similar interactions as the $J_z > 1 $ but are a mixture of the two graphs due to stating qubits in alternating states.

# %% [markdown]
# For the rest of this report, we focus on the $\ket{00000}$ initial state to reduce the number of plots and simplify comparisons between methods. Having already examined the different initial configurations, we have established that while they lead to different dynamics, the qualitative behaviour of the simulation methods we wish to compare, and the differences between them, will be the same. Therefore, restricting to a single representative initial state does not affect the conclusions of our analysis.

# %% [markdown]
# ## 3. Our built Suzuki-Trotter function
#
# Simulating the time evolution of quantum many body systems on quantum computers has proved to be far more useful for larger number of bodies and timescales than a classical system. We have built our own Suzuki-Trotter (S-T) code to simulate this function in Qiskit using own implementation of a quantum S-T decomposition circuit to fully understand how the model works.
#
# The Suzuki-Trotter decomposition approximates the time evolution operator by splitting the Hamiltonian into individually exponentiable terms[12]:
#
# $$U(t) = e^{-iHt} \approx \left(\prod_k e^{-i h_k \Delta t}\right)^n + \mathcal{O}(\Delta t^2)$$
#
# where $H = \sum_k h_k$ and $\Delta t = t/n$. Each $e^{-ih_k \Delta t}$ is a simple rotation gate directly implementable on quantum hardware.
#
# Trotterisation maps naturally onto quantum circuits with fixed, shallow depth per step. For comparison to IBM hardware the circuit depth must remain fixed and we therefor fix the Trotter circuit structure (controlled by `reps`), and vary $\Delta t$ to sample different times. This keeps the circuit depth constant and matches how the IBM jobs are actually submitted.
#
# The error in the approximation decreases as $\Delta t \to 0$ (more Trotter steps), but on hardware, smaller $\Delta t$ means more repetitions and deeper circuits. While higher order $\Delta t$  means bettter scaling, they require more gates per Trotter step, which on noisy hardware is not effective for collecting usable data. This makes the Suzuki-Trotter method a good model for hardware in quantum computation for small intervals of time.

# %%
def trotter_step_1st_order(circuit, H, dt):
    """
    Apply a single 1st-order Trotter step to a QuantumCircuit.

    :param circuit: QuantumCircuit to append gates to
    :param H:       SparsePauliOp Hamiltonian
    :param dt:      timestep size
    :returns:       updated circuit
    """
    for pauli_str, coeff in H.to_list():
        pauli_op = Pauli(pauli_str)
        gate = PauliEvolutionGate(pauli_op, time=dt * coeff.real)
        circuit.append(gate, range(circuit.num_qubits))
    return circuit

def first_order_trotter(H, t, n_steps, num_qubits=None):
    """
    Build a circuit implementing first-order Trotterised time evolution.

    :param H:          SparsePauliOp Hamiltonian
    :param t:          total evolution time
    :param n_steps:    number of Trotter steps
    :param num_qubits: system size (inferred from H if None)
    :returns:          QuantumCircuit
    """
    if num_qubits is None:
        num_qubits = H.num_qubits
    qc = QuantumCircuit(num_qubits)
    dt = t / n_steps
    for _ in range(n_steps):
        trotter_step_1st_order(qc, H, dt)
    return qc

# %% [markdown]
# ## 3.1. Data from our Suzuki-Trotter
#
# We now build the Suzuki-Trotter program and plot the expectation value time evolutions for each qubit and all three directions. We expect our Suzuki-Trotter data to exactly match the 'classical' results due to how this method is implemented.
#
# We will once again observe the symmetry for the uneven number of qubits as well as the different oscillations and initial values for the three different directions.

# %%
display(Image(filename='trotter_vs_exact_xyz.png'))

# %% [markdown]
# As shown above, the manually built Suzuki-Trotter does almost exactly match what we had in Section 2. This will also be shown and explained with the Suzuki-Trotter Qiskit function in Section 6.
#
# The alignment between these two methods validates our implementation of the decomposition. Any observed differences can be explained by the Trotter error arising from the finite timestep, rather than errors in the circuit construction.

# %% [markdown]
# ## 4. Noise
#
# Quantum computers are extremely noisy devices so the above data would not be close to expected data from real devices. We can artificially add noise to the system to make up for this diffrence.
#
# Many types of noise contribute to the overall system noise with extranal intereference, qubit flips and decoheremce and more, These error rates lie betwwen 0.01 and 0.0001 so rates within this range have been investigated, where the error rate is the probability of a physical qubit having an error due to any type of noise. These errors are bit flips and phase flips discussed in Section 1.1 that change the readout data making quantum systems fairly unreliable.
#
# Coreection methods can be applied to mitigate the noise from qubits themselves and quantum computers by rncoding many physical qubits onto one logical qubit, but this project will only discuss the expected values with erros modeled into them.
#
# Pauli operations are errors on qubits. These change the information on a given qubit in GF2 (modulus 2) space as below[13]:
#
# $$ X \ket{0} = \ket{1} \quad X \ket{1} = \ket{0}$$
#
# $$ Z \ket{0} = \ket{0} \quad Z \ket{1} = -\ket{1}$$
#
# Since qubits are unstable, these Pauli opertors become erros in quantum the information and contribute to the overall noise of quantum computing systems like the IBM quantum computer we have tesed our data on. The X erros are known as bit flips erros and Z errors are phase flip errors, giving qubits two types of erros possible, one more than classical bit data and Y is a phase of both X and Z acting on the same qubit.
#
# These gates can be controlled by an ancilla qubit and make the operation Controlled X (CNOT) where the qubit only experiences respective bit flip if the controlled/ancilla qubit is a 1. These operations give the depth of a circuit and accumulate more errors as its increaed.

# %%
def trotter_with_noise_model(L, Jz, steps, t_tot, error_rate, noise_type='depolarizing', allzeros=True):
    """
    noise_type: 'X'          -> bit-flip only (Pauli X error on each qubit of CX)
                'Z'          -> phase-flip only (Pauli Z error on each qubit of CX)
                'depolarizing' -> full depolarizing (X, Y, Z equally)
    """
    H  = hamiltonian1(L, Jz)
    dt = t_tot / steps

    noise_model = NoiseModel()

    if noise_type == 'depolarizing':
        error_2q = depolarizing_error(error_rate, 2)

    elif noise_type == 'X':
        # Bit-flip error on each qubit independently (tensor product of single-qubit X errors)
        single = pauli_error([('X', error_rate), ('I', 1 - error_rate)])
        error_2q = single.expand(single)   # 2-qubit version via tensor product

    elif noise_type == 'Z':
        # Phase-flip error
        single = pauli_error([('Z', error_rate), ('I', 1 - error_rate)])
        error_2q = single.expand(single)

    noise_model.add_all_qubit_quantum_error(error_2q, ['cx'])

    psi0       = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    simulator  = AerSimulator(method='statevector', noise_model=noise_model)
    states     = [np.array(psi0)]
    current_sv = np.array(psi0)

    qc_step = QuantumCircuit(L)
    trotter_step_1st_order(qc_step, H, dt)
    qc_step = transpile(qc_step, simulator)

    for _ in range(steps):
        qc_run = QuantumCircuit(L)
        qc_run.set_statevector(current_sv)
        qc_run = qc_run.compose(qc_step)
        qc_run.save_statevector()
        result     = simulator.run(qc_run).result()
        current_sv = np.array(result.get_statevector())
        states.append(current_sv)

    return states

# %% [markdown]
# The code to plot these functions over time is in the extracode.py file under 'our trotter with noise'. This picks noise levels between hardware ranges of 0.001 to 0.01 error tares, which represent the probability of getting an error on a qubit. The steps of the trotter have to be taken into account, since the more steps, the higher this probability is with a defined error rate so the chosen 0.001 error rate good value for a noisy system[14] that can show the effect of errors. Quantum computing companies are aiming to make qubits far below these rates, and we will use ibms built in functions to display efficient, hardware realistic erros on the qiskit trotter in Section 6.

# %%
display(Image(filename='obs_X_rate_0_001.png'))

# %%
display(Image(filename='obs_Y_rate_0_001.png'))

# %%
display(Image(filename='obs_Z_rate_0_001.png'))

# %% [markdown]
# The data shows that as the error rates increase to match more realistic hardware conditions, the values deviate further from the expeceted values simulated with the classical model. This is expected since noise interefres with qubits and the system itself and changes the propogation of a state under a given hamiltonian. The noise from just X and just Z errors, which combine make Y(=iXZ) when both acting on one qubit. The graphs show this is the case and the expectation values spike more in independant X and Z erros untill they are combined.

# %% [markdown]
# ## 5. McLachlan Variational Time Evolution
#
# The main drawback of using Trotterisiation in a circuit as built above is the CNOT depth which increases over time and contributes to errors and computational costs of runing the simulations. Other methods, like the McLachan method is a variational method restricted to a specific ansatz circuit. This keeps the CNOT depth constant over time, so could be a useful tool for harrware realistic simulations of qubits where gate errors accumulate with CNOT depth.
#
# The state in this hamiltonian is restricted to a parametrised ansatz $|\psi(\theta)\rangle$, where McLachlan's variational principle gives [15]:
#
# $$M\dot{\theta} = V$$
#
# $$M_{ij} = \mathrm{Re}\langle \partial_i \psi | \partial_j \psi \rangle, \qquad V_i = \mathrm{Im}\langle \partial_i \psi | H | \psi \rangle$$
#
# We numerically differentiate:
# $$\partial_i \psi \approx \frac{|\psi(\theta + \epsilon e_i)\rangle - |\psi(\theta - \epsilon e_i)\rangle}{2\epsilon}$$
#
# This method then computes $M$ and $V$ at each timestep, to solve the system $M\dot{\theta} = V$ for velocities  velocities $\dot{\theta}$. The accuracy of the variational method depends on how well the ansatz represents the evolved state $e^{-iHt}|\psi_0\rangle$ which is the Hamiltonian acting on the quantum states.

# %%
n_layers = 4   # depth of ansatz

pauli_x  = np.array([[0,  1 ], [1,   0]], dtype=complex)
pauli_y  = np.array([[0, -1j], [1j,  0]], dtype=complex)
pauli_z  = np.array([[1,  0 ], [0,  -1]], dtype=complex)
identity = np.eye(2, dtype=complex)

def observable_matrix(L, qubit, pauli):
    """Full 2^L × 2^L matrix for a single-site Pauli operator."""
    ops = [identity] * L
    ops[qubit] = pauli
    return ft.reduce(np.kron, ops)

def expectation_value(psi, obs):
    return np.real(np.vdot(psi, obs @ psi))

def ansatz_circuit(theta, L):
    """
    Ansatz: n_layers of (Ry, Rz, Rx) on each qubit followed by a CNOT chain.
    len(theta) must equal 3 * L * n_layers.
    """
    qc = QuantumCircuit(L)
    k  = 0
    for _ in range(n_layers):
        for q in range(L):
            qc.ry(theta[k], q); k += 1
            qc.rx(theta[k], q); k += 1
            qc.rz(theta[k], q); k += 1
        for q in range(L - 1):
            qc.cx(q, q + 1)
    return qc

def psi_theta(theta, L):
    """
    Args:
        theta (float): velocity
        i (int): each qubit 
        L (int): number of qubits
        eps (float): scales the system, Defaults to 1e-6.

    Returns:
        the derivative of the velocity of the evolution 
    """
    return Statevector(ansatz_circuit(theta, L)).data

def psi_derivative(theta, i, L, eps=1e-6):
    """_summary_

    Args:
        theta (_type_): _description_
        i (_type_): _description_
        L (_type_): _description_
        eps (_type_, optional): _description_. Defaults to 1e-6.

    Returns:
        _type_: _description_
    """
    tp = theta.copy(); tp[i] += eps
    tm = theta.copy(); tm[i] -= eps
    return (psi_theta(tp, L) - psi_theta(tm, L)) / (2 * eps)

def build_M(theta, L):
    """

    Args:
        theta (float): velocity
        L (int): number of qubits

    Returns:
        M over time
    """
    n      = len(theta)
    derivs = [psi_derivative(theta, i, L) for i in range(n)]
    M      = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            M[i, j] = np.real(np.vdot(derivs[i], derivs[j]))
    return M

def build_V(theta, H, L):
    """

    Args:
        theta (float): velocity
        H (array): hamiltonian
        L (int): number of qubits

    Returns:
        V over time
    """
    psi  = psi_theta(theta, L)
    Hpsi = H @ psi
    n    = len(theta)
    V    = np.zeros(n)
    for i in range(n):
        V[i] = np.imag(np.vdot(psi_derivative(theta, i, L), Hpsi))
    return V

def fit_theta_to_state(psi_target, L, n_params, n_restarts=10):
    """
    Find theta minimising 1 - |⟨psi_target|psi(theta)⟩|².
    Uses multiple random restarts to avoid local minima.
    """
    best_theta, best_loss = None, np.inf

    def loss(theta):
        return 1.0 - abs(np.vdot(psi_target, psi_theta(theta, L))) ** 2

    for _ in range(n_restarts):
        t0  = np.random.uniform(-np.pi, np.pi, n_params)
        res = minimize(loss, t0, method="L-BFGS-B")
        if res.fun < best_loss:
            best_loss, best_theta = res.fun, res.x

    print(f"Fit overlap loss: {best_loss:.6f}  (0 = perfect)")
    return best_theta

def mclachlan_evolve(theta0, H, L, dt, steps):
    """

    Args:
        theta0 (float): initial vel
        H (_type_): hamiltonian
        L (int): number of qubits
        dt (float): increments of time
        steps (float): number of increments

    Returns:
        states over time
    """
    theta  = theta0.copy()
    states = [psi_theta(theta, L)]
    reg    = 1e-8
    for step in range(steps):
        M         = build_M(theta, L)
        V         = build_V(theta, H, L)
        theta_dot = np.linalg.solve(M + reg * np.eye(len(theta)), V)
        theta    += dt * theta_dot
        states.append(psi_theta(theta, L))
        if (step + 1) % 50 == 0:
            print(f"  step {step+1}/{steps}")
    return states

# %% [markdown]
# The state is then evolved over time and the paths of the expectation values $\langle X_i(t)\rangle$, $\langle Y_i(t)\rangle$, $\langle Z_i(t)\rangle$ are recorded and plotted below.

# %%
L       = 4
Jz      = -1.1
steps   = 300
t_total = 5.0
dt      = t_total / steps
allzeros = True

# %%
display(Image(filename='mchalchandata.png'))

# %% [markdown]
# The plots show the expectation values $\langle X \rangle$, $\langle Y \rangle$, and $\langle Z \rangle$ for each qubit over time under McLachlan variational evolution. All expectation values show some coherent evolution, yet they all appear to be unstable and irregular at various points. This is due to the limits of the ansatz at `n_layers = 4` and so the variational manifold cannot accuraley depict the evolved state over longer timescales. The fixed ansatz of the circuit also limits the $\langle Z \rangle$ values, where they now rotate abour 0 rather than the expected +1.
#
# Increasing `n_layers` would reduce this drift, but at the cost of greater CNOT depth and runtime[16]. Therefore, it would be redundant to increase the layers to achieve something akin to the Trotterisation of the hamiltionian. Furthermore, the increased circuit depth would worsen performance on real hardware, where gate errors accumulate with depth. This contributes to our decision to use Trotterisation as the primary simulation method throughout this project. The next section will introduce methods to use Trotterisation to see how the Hamiltonain would actually be run on a q-chip (quantum chip).

# %% [markdown]
# ## 6. Qiskit inbuilt trotter analysis
#
# <!-- **Kyran: i will write intro for this: - qiskit's implementation, explain how theoretically do ST (maybe repeat what hugp says when first introducing it), explain why this isnt feasible on real chip (gets too deep and takes forever, also cant really measure at each step without creating a new circuit in real life) - actualy physical implementation, expalin (keeping circuit depth the same with time,keep reps the same, change final $dt$ - see what its called in math seciton) (see docstring), explain how testing both and see how they perform (Without any noise)** - **can compare the physical implementationwith noisy simulation and actual ibm code results** -->
#
# For our physical implementation of the Suzuki-Trotter method on a physical quantum chip, we will use qiskit's built-in `SuzukiTrotter`[17] method for building the S-T circuit.
#
# There are two main ways to implement a Suzuki-Trotter circuit to simulate the time evolution of a quantum system:
#  - i) The first way ($dt$ costant) is what was implemented above, with our self built S-T in section 3. This method consists of appending an additional single-trotter-step circuit to evolve our system by a set $dt$. This is repeated (with a possible measurement at each time $t$), until you reach your desired final time of evolution $T$. With a constant $dt$, this method creates very long, deep circuits for large time $T$ (as mentioned in section 5), as S-T is built on the assumption of small $dt$. While this method provides very accurate results for sufficiently small $dt$, it creates circuits that are far too deep to run on physical chips -- the noise from consecutive CNOT gates would take over quite quickly[18], and the time taken to run would exceed reasonable quantum computing allotment (its very expensive!). Hence it is more of a theoretical implementation of Suzuki-Trotter. With qiskit's built-in, this method is implemented below in the `TheoreticalST` function.
#  - ii) The second way ($dt$ variable) sets the circuit depth constant, such that noise has a reasonably constant effect throughout the evolution. This method builds a Suzuki-Trotter circuit with a set number of n `reps` (trotter steps), that each evolve the system by $dt$. For each desired time evolution point $t$, one sets $dt=t/n$ such that you evolve to $t$ by the end of the S-T circuit. This is then performed for each $t$ until final $T$ is reached with $dt=T/n$. With this implementation, one can time evolve to any time value, and the circuit depth does not change. This method is much more compatible with physical quantum chips[8], and our implementation is hence called `PhysicalST` below. The downside of this method however, is that, even without noise, the results from the Suzuki-Trotterization start to diverge from the true evolution at high $t$, as the first order S-T approximation is based on small $dt$. This can be seen in the plots below.
#
# It is this second method ii) that we will implement on the IBM chip and compare to, with noise.
#
# <!-- This does the same as our trotter but with a function in qiskit, this data will be the best to fit to IBMs quantum computer data. -->
#
# <!-- **Tamara : Add intro, what's going on here, introduce the model, how is it different to the one we created, why is one or the other better, why is this data better for IBMs qc data** -->

# %%
def TheoreticalST(L, Jz, qubit_measured, direction_measured,
                  steps, t_tot, allzeros, order=1, reps=1):
    """
    Qiskit Suzuki-Trotter: growing circuit (theoretical, not hardware-compatible).
    Appends one ST timestep circuit `steps` times to build up the full evolution.

    :param L:                  (int)   number of qubits
    :param Jz:                 (float) anisotropy parameter
    :param qubit_measured:     (int)   qubit index (1-based)
    :param direction_measured: (str)   'X', 'Y', or 'Z'
    :param steps:              (int)   number of time steps
    :param t_tot:              (float) total evolution time
    :param order:              (int)   Suzuki-Trotter order (default 1)
    :param reps:               (int)   ST repetitions per appended step (default 1)
    :param allzeros:           (bool)  for Jz>1: True→|000…⟩
    :returns: (t_values, measurements) as np.arrays
    """
    hamiltonian = hamiltonian1(L, Jz)
    dt   = t_tot / steps
    gate = PauliEvolutionGate(operator=hamiltonian, time=dt)
    st   = SuzukiTrotter(order=order, reps=reps,preserve_order=False)
    circ = st.synthesize(gate)

    paulistring = "".join(
        direction_measured if i == qubit_measured - 1 else "I" for i in range(L)
    )
    obs       = SparsePauliOp([paulistring], coeffs=[1])
    estimator = StatevectorEstimator()

    psi0 = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    qc   = QuantumCircuit(L)
    qc.initialize(psi0.data)

    measurements = []
    for _ in range(steps):
        qc.append(circ, range(L))
        result = estimator.run(pubs=[(qc, [obs])]).result()
        measurements.append(result[0].data.evs[0])

    t_values = np.array([dt * (t+1) for t in range(steps)])
    return t_values, np.array(measurements)


def PhysicalST(L, Jz, qubit_measured, direction_measured,
               steps, t_tot, allzeros, order=1, reps=5):
    """
    Qiskit Suzuki-Trotter: fixed-depth circuit (hardware-compatible).
    Rebuilds a fresh circuit for each time point, keeping circuit depth constant.
    This is the method similar to what is submitted to IBM quantum hardware.

    :param L:                  (int)   number of qubits
    :param Jz:                 (float) anisotropy parameter
    :param qubit_measured:     (int)   qubit index (1-based)
    :param direction_measured: (str)   'X', 'Y', or 'Z', which projection operator is applied to the measured qubit
    :param steps:              (int)   number of time points sampled
    :param t_tot:              (float) total evolution time
    :param order:              (int)   Suzuki–Trotter order (default 1)
    :param reps:               (int)   fixed circuit depth in Trotter steps (default 5)
    :param allzeros:           (bool)  for Jz>1: True→|000…⟩, False→|111…⟩ (default True)
    :returns: (t_values, measurements) as np.arrays
    """
    hamiltonian = hamiltonian1(L, Jz)
    st = SuzukiTrotter(order=order, reps=reps, preserve_order=False)

    paulistring = "".join(
        direction_measured if i == qubit_measured - 1 else "I" for i in range(L)
    )
    obs       = SparsePauliOp([paulistring], coeffs=[1])
    estimator = StatevectorEstimator()   # replace with IBM Estimator to run on hardware

    psi0    = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    dt      = t_tot / steps
    t_values = np.array([dt * t for t in range(steps)])

    measurements = []
    for timeval in t_values:
        gate = PauliEvolutionGate(operator=hamiltonian, time=timeval)
        circ = st.synthesize(gate)
        qc   = QuantumCircuit(L)
        qc.initialize(psi0.data)
        qc.append(circ, range(L))
        result = estimator.run(pubs=[(qc, [obs])]).result()
        measurements.append(result[0].data.evs[0])

    return t_values, np.array(measurements)

# %% [markdown]
# The following plots show both implementations i) and ii) of the Suzuki-Trotter method for qubits 1, 2, and 3 (as the rest are symmetric) of 5 **FIX THE PLOTS**. These are calculated with qiskits inbuilt `SuzukiTrotter`, via our functions `TheoreticalST` and `PhysicalST`, respectively.

# %%
display(Image(filename='theoretical_vs_exact1.png'))

# %% [markdown]
# As discussed previously, the theoretical implementation of S-T above follows the true time evolution almost exactly, as expected. This shows the first order S-T is a good method for simulating time evolution, when $dt$ is small enough. Here, we chose a $dt$ of **CHECK** and appended a total of **num** steps to a final time of $5$. As expected, this etremely deep circuit takes a while to run and so the code is included in `extracode.py`.

# %% [markdown]
# **Tamara : Interpret results, difference between 3 graphs, different to what we previously had?, what's going on, what's the next step**

# %% [markdown]
# Next, we have the implementation of the Suzuki-Trotter Method that is compatible with a physical limit on circuit depth. Here the depth of the circuit (number of `reps` per Suzuki-Trotter circuit) stays the same, but the final time $t$ is changed to acquire many different data points. Again plotting the first three qubits, the below plots are made with `PhysicalST` with **NUM of REPS tot time ETC** also **FIX PLOTS**

# %%
display(Image(filename='physical_vs_exact1.png'))

# %% [markdown]
# As one can see in the above plots, this method starts to diverge from the exact result at higher times, as then the individual $dt$ s of the `reps` inside the Suzuki-Trotterization are relatively large, and it becomes a less accurate approximation. This divergence from the exact time evolution solution is before simulating noise, and just due to the approximation of the first order S-T method.

# %% [markdown]
# **Kyran :** yap about it -- starts to diverge at higher times

# %% [markdown]
# ## 5.2 IBM Fez noise model

# %%
# logging into shae's ibm to do ibm 

QiskitRuntimeService.save_account(
    channel='ibm_quantum_platform',
    instance='open-instance',
    token='ZloPoqK6x9xIzGYUhKPmbAB2iCpFL4pGZH2WKQppTtfq',
    overwrite=True,
    set_as_default=True
)

# building ibm_fez noise model (see workshop 4)
service = QiskitRuntimeService()
real_backend = service.backend("ibm_fez")
noise_model = NoiseModel.from_backend(real_backend)
ibm_fez_simulator = AerSimulator(method='density_matrix', noise_model=noise_model)

pauli_map = {'X': np.array([[0,1],[1,0]], dtype=complex),
            'Y': np.array([[0,-1j],[1j,0]], dtype=complex),
            'Z': np.array([[1,0],[0,-1]], dtype=complex)}

def PhysicalST_with_ibm_noise(L, Jz, qubit_measured, direction_measured, steps, t_tot, allzeros, order=1, reps=5, simulator=ibm_fez_simulator):
    """
    Qiskit Suzuki-Trotter with noise from IBM Fez: fixed-depth circuit. 
    Mirrors PhysicalST but runs through AerSimulator with a noise model applied, making it a better proxy for real 
    IBM hardware than the noiseless statevector.

    :param L:                   (int)   number of qubits
    :param Jz:                  (float) anisotropy parameter
    :param qubit_measured:      (int)   qubit index (1-based)
    :param direction_measured:  (str)   'X', 'Y', or 'Z'
    :param steps:               (int)   number of time points sampled
    :param t_tot:               (float) total evolution time
    :param allzeros:            (bool)  for Jz>1: True→|000…⟩
    :param order:               (int)   ST order (default 1)
    :param reps:                (int)   fixed circuit depth in Trotter steps (default 5)
    :param error_rate:          (float) depolarizing error rate on CX gates (CHANGE)
    :returns: (t_values, measurements) as np.arrays
    """
    hamiltonian = hamiltonian1(L, Jz)
    st = SuzukiTrotter(order=order, reps=reps)

    target = simulator.target
    pm = generate_preset_pass_manager(target=target, optimization_level=3)

    obs_matrix = observable_matrix(L, qubit_measured - 1, pauli_map[direction_measured.upper()])

    psi0 = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    dt = t_tot / steps
    t_values = np.array([dt * t for t in range(steps)])
    measurements = []

    for timeval in t_values:
        gate = PauliEvolutionGate(operator=hamiltonian, time=timeval) 
        circ = st.synthesize(gate)

        qc = QuantumCircuit(L)
        qc.initialize(psi0.data)
        qc.append(circ, range(L))
        qc.save_density_matrix()  

        qc_t = pm.run(qc)
        result = simulator.run(qc_t, shots=10000).result()
        dm = result.data()['density_matrix']
        
        # Build the full observable matrix and compute Tr(rho * O) (the expectation value of a density matrix rho)
        expval = np.real(np.trace(dm.data @ obs_matrix)) # exp values of the observable matrix
        measurements.append(expval)

    return t_values, np.array(measurements)

# %%
display(Image(filename='image.png'))

# %%
display(Image(filename='ibmFez2.png'))

# %% [markdown]
# noise- same as noise on our model but this is what we will compare to the IBM data
#
# **see what shae does** here should we use a model from actual chip backend like `ibm_fez` or noise for each CNOT gate like the noise simulations above? In the latter case, you would then have to decompose or transpile... which one for adding noise to CNOTs...? presumebly simulating from an actual chip would take care of this question.

# %%
#scape time plots -fourier transform fits - inbuilt python function imshow

# %% [markdown]
# ## 7. IMB quantum computer data
#
# **add yap**
# Talk about circuit depth, add experimentation plots (Kyran). aiming for ~50 depth max because... noise takes over? Also maybe do to timestep $t=6$ to see noise take over... Kyran, look at notes from what he was saying about circuit depth etc. When actually doing on IBM, do uneven timesteps, just a few data points, to see if matches with classical and with PhysicalST

# %% [markdown]
# Realistically, so the innate noise of the quantum chip doesn't take over our results, we want the CNOT circuit depth to stay around 60 to 100, as these are the gates that introduce noise.[19] As every trotter step is $\sim6$ CNOT gates for every pair of qubits (as a unitary gate in general takes $3$ CNOTs to reproduce), this greatly limits the number of `reps` in our Suzuki-Trotterization. The plots below show the exploration of circuit depth, using the `decompose` function, which decomposes the circuit into fundamental gates, and the `transpile` function, which implements the circuit in a way specific to a physical chip: in our case our examples are with `ibm_fez`.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService, Session
import json

# %%
#setting up backend to real chip, so can test noise etc., and eventually run
chipname = 'ibm_fez'          #when actually running, can choose least busy
try:
    with open('../apikey.json') as file:
        api_key = json.load(file)
except:
    print("No API key found: make sure to modify this code and enter your API key manually in the below command.")

QiskitRuntimeService.save_account(channel='ibm_quantum_platform', instance = 'open-instance', token=api_key["apikey"], overwrite=True, set_as_default=True)
service = QiskitRuntimeService()                   #load saved credentials for API key
real_backend = service.backend(chipname)           #backend for specific chip

# %%
# defining a function that calculates circuit depth of a given Suzuki-Trotter circuit, as implemented in PhysicalST.
# calculates depth for both the decomposed circuit and the transpiled circuit
def circuitdepths(L,Jz,qubit_measured,direction_measured,backendobject,order=1,reps=5,allzeros=True,optimization_num=3):
    '''
    Calculates the circuit depth for a given Suzuki-Trotter circuit (in the same way that PhysicalST builds it), 
    for the transpiler (given a specific backend object) and for decomposing into fundamental gates.

    returns tuple (tranpile_depth, decompose_depth)

    :param L:                  (int)        number of qubits
    :param Jz:                 (float)      anisotropy parameter
    :param qubit_measured:     (int)        qubit index (1-based)
    :param direction_measured: (str)        'X', 'Y', or 'Z', which projection operator is applied to the measured qubit
    :param backendobject:      (IBMBackend) an <IBMBackend> object, created with QiskitRuntimeService().backend('chipname')
    :param order:              (int)        Suzuki-Trotter order (default 1)
    :param reps:               (int)        fixed circuit depth in Trotter steps (default 5)
    :param allzeros:           (bool)       for Jz>1: True→|000…⟩, False→|111…⟩ (default True)
    :param optimization_num:   (int)        0 to 3, optimization level for transpiling, higher levels → potentially more optimized circuits, at the expense of longer transpilation time (default 3)
    :returns: (transpile_depth,decomp_depth) as np.arrays
    '''

    hamiltonian = hamiltonian1(L,Jz)
    st = SuzukiTrotter(order=order, reps=reps,preserve_order=False)

    # Define the observable we wish to estimate
    paulistring = "".join(
        direction_measured if i == qubit_measured - 1 else "I" for i in range(L)
    )
    obs       = SparsePauliOp([paulistring], coeffs=[1])

    # Define the 'Estimator' primitive used to measure/estimate expectation values of observables
    estimator = StatevectorEstimator()

    psi0 = initialise(Jz, L, allzeros=allzeros, rotate_middle=True)
    qc   = QuantumCircuit(L)
    qc.initialize(psi0.data)

    #just picking a dt time value to build circuit with, this function only tests depth, so doesn't really matter (although seems to affect transpiling very minimally, why?)
    t_val = 0.01
    gate = PauliEvolutionGate(operator=hamiltonian,time=t_val)
    circ = st.synthesize(gate)
    qc.append(circ,[i for i in range(L)])

    cnotdepth = qc
    qc_t = transpile(cnotdepth,backend=backendobject,optimization_level=optimization_num) #transpiled circuit
    
    return (qc_t.depth(),cnotdepth.decompose().depth())

# %% [markdown]
# **Kyran : talk about what I'm plotting and what it means (maybe after the plots), what we're aiming for?** also is transpile depth even important? why is it so high?? last mystery to figure out...
#
# Below, we have plotted the decomposed circuit depth and transpiled circuit depth for different numbers of qubits and different values of S-T `reps`. This is done to gauge the maximum amount of qubits and reps we can use for the most accurate result from the IBM chip, while staying out of the regime where noise takes over.

# %%
#plotting circuit depth as a function of number of qubits, for 7, 10 and 13 S-T reps
qubitnums = list(range(1,11))
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, rep in zip(axes, [7,10,13]):
    t_depth = [circuitdepths(L,Jz=2,qubit_measured=1,direction_measured='Z',backendobject=real_backend,order=1,reps=rep)[0] for L in qubitnums]
    d_depth = [circuitdepths(L,Jz=2,qubit_measured=1,direction_measured='Z',backendobject=real_backend,order=1,reps=rep)[1] for L in qubitnums]

    ax.plot(qubitnums,t_depth,label='transpile')
    ax.plot(qubitnums,d_depth,label='decompose')
    ax.axhline(y=60,c='grey',ls='--',label='Depth of 60')
    ax.set_xlabel(r'Number of Qubits')
    ax.set_ylabel(rf'Circuit Depth')
    ax.set_title(rf'Circuit Depth as a Function of Num. of Qubits, for {rep} S-T reps')
    ax.set_ylim([-10, 450])
    ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# The above plot, for 7, 10, and 13 S-T `reps` respectively, shows how circuit depth grows as a function of number of qubits. The grey dotted line shows a depth of 60, as bench mark for the noisy regime. For the decomposed circuit, after 3 qubits, the depth does not increase with number of qubits, as expected from the brickwork design of the ST circuit discussed at the beginning of this report.
#
# The transpiled circuit depth, on the other hand is quite quite high and does grow with qubit number, which signals that maybe this depth value is not what we're expecting. It could be that qiskit's `.depth()` method measeures soemthing different from the transpiled circuit than the decomposed circuit, or circuit depth when transpiled should be measured by a different bench mark. It was investigated that this discrpancy is *not* due to the qubits being mapped far away on the physical chip, as qiskit automatically takes care of this [cite-transpile func documentation]. This issue could be investigated in the future with more time.

# %% [markdown]
# **Kyran** talk about how depth is constant with num of qubits, as exepected... more yap  **transpile depth mystery...**
#
#
# then: what these next plots are

# %% [markdown]
# Now, plotting as a function of Suzuki-Trotter steps:

# %%
#plotting circuit depth as a function of S-T reps, for 4, 8 and 10 qubits
STreps = list(range(1,14))
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, L in zip(axes, [4,8,10]):
    t_depth = [circuitdepths(L,Jz=2,qubit_measured=1,direction_measured='Z',backendobject=real_backend,order=1,reps=r)[0] for r in STreps]
    d_depth = [circuitdepths(L,Jz=2,qubit_measured=1,direction_measured='Z',backendobject=real_backend,order=1,reps=r)[1] for r in STreps]

    ax.plot(STreps,t_depth,label='transpile')
    ax.plot(STreps,d_depth,label='decompose')
    ax.axhline(y=60,c='grey',ls='--',label='Depth of 60')
    ax.set_xlabel(r'Number S-T reps')
    ax.set_ylabel(rf'Circuit Depth')
    ax.set_title(rf'Circuit Depth as a Function of S-T reps, for {L} Qubits')
    ax.set_ylim([-10, 500])
    ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# The above plot, for 4, 8, and 10 qubits respectively, shows how circuit depth grows as a function of S-T reps. For the decomposed circuit, the circuit depth increases linearly with S-T reps, as expected, as each step intorduces approximately 6 CNOT gates.

# %% [markdown]
# **THIS IS WHERE I GOT TO, MORE TO DO** KYRAN - do just first three qubits, rerun code, etc.
# **Kyran** explain plots more
#
# **Kyran** explain plots more Talk about what we're choosing for chip, and why
#
# Evidently, we cannot perform these calculations with the hundreds (or even tens) of S-T reps as shown in the above plots. To stay out of the noisy regime, we will choose  ...  For a more accurate comparison with our eventual physical chip code, lets then plot what the Suzuki-Trotter method looks like (without noise), compared to the exact time evolution, for 4 qubits and 9 Suzuki-Trotter reps: **maybe change numb of qubits etc. do 10 reps**

# %%
# --- 6.n PhysicalST vs Exact: 9 S-T reps ---
L, Jz, steps, t_tot, reps = 5, 1.1, 150, 5, 9

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, direction, label in zip(axes, ['X','Y','Z'], ['X','Y','Z']):
    for q, col in zip(range(1, L//2 + 1), ['orangered','gold','steelblue']):#,'m']):
        t_ex, ex   = ClassicalComparison(L, Jz, q, direction, steps, t_tot)
        t_st, st_  = PhysicalST(L, Jz, q, direction, steps, t_tot, allzeros=True, order=1, reps=reps)
        ax.plot(t_ex, ex,       label=rf'Exact $\langle {label}_{q}\rangle$',c=col)
        ax.plot(t_st, st_, '--', label=rf'PhysicalST $\langle {label}_{q}\rangle$',c=col)
    ax.set_xlabel(r'$t\ (eV^{-1})$')
    ax.set_ylabel(rf'$\langle {label}(t) \rangle$')
    ax.set_title(rf'PhysicalST vs Exact: $\langle {label} \rangle$, {reps} S-T reps, no noise')
    ax.set_ylim([-1.1, 1.1])
    ax.legend(fontsize=7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explain what seeing**
#
# **do again with noise?** Now, with noise, this starts to diverge quite quickly, and our accuracy decreases dramatically. This is more in line with whats expected, like the examples in class
#
# ***can we fix this, or find a better way?***

# %%
#here plot same as above, but with Aer noise simulation of real chip

# %% [markdown]
# Now, we are ready to test on a real quantum chip. This will allow us to observe the difference between the different methods and how close they are to plots obtained through a real quantum chip. All previous sections, and the noise Section 4. in particular, should explain the expectation value time evolutions we will obtain with this test.
#
# We decide to study the same system as previously : 5 qubits, $\ket{00000}$, over a period of $5(eV)^{-1}$. We choose to plot the time evolutions for the expectation values of all directions for the middle qubit. We choose this setup because the longer the period of time, the more the error will propagate for the 'classical' and 'physical' simulations to which we are comparing the real quantum chip plot. We choose the middle qubit as it is the most interesting to study due to the bigger oscillations, as explained previously. We found this initialisation to be the cleanest and most efficient, which is necessary due to the limited amount of time we have on the IBM quantum computer.
#
#
#
#  **could def don more data points than originally thought, because is quite fast, but should still mention why doing only separate points** aiming for accuracy -- we havent really talked about what our aim is in all of this...
#
# **explain how coded it-- spearate jobs for each**

# %% [markdown]
# For actual ibm chip, maybe just the second qubit, that seems to follow quite well, why tho?

# %%
display(Image(filename='IBM_Ydirection_5qubits_Nb3_5secs_lin.png'))

# %%
display(Image(filename='IBM_Ydirection_5qubits_Nb3_5secs.png'))

# %%
display(Image(filename='IBM_Xdirection_5qubits_Nb3_5secs.png'))

# %%
display(Image(filename='IBM_Zdirection_5qubits_Nb3_5secs.png'))

# %% [markdown]
# **then talk about results -- is it shitty or good ? noise still sucha probelem in quantum computing? cant or can show quantum advantage yet?**

# %% [markdown]
# ## 8. Conclusion
#
# The simulation of the time evolution of the XXZ Heisenberg Hamiltonian was done using Trotterisation and McLachan, concluding that Trotterisation was a much better method to be using than a variational one for many body qubit systems in our simulations due to the structure of the ansatze in common variational methods.
#
# Noise was investigated alongside the simulation of qubits for our trotter (for testing) and the qiskit trotter (for comparison to IBM data). These showed us how errors on quantum data appear in quantum computers and what this does to the data. Including investigations into the bit and phase flips that change quantum infmation in a qubit, and decoherent noise where all errors act with equal probability.
#
# Simulating a larger number of qubits in many body simulations still remains challange when aiming for accuracy of data while maximising data points. Our IBM data focuses just on the accuracy of points of collectable data of the evolved qubit states over a short time period of $5 eV^{-1}$. These results validated our noise models since they were far noisier than or classical and trotterisation methods of evolution, proving that quantum computer hardware noise is a massive contributing factor to errors in reeults from simulations.
#
# Incorporating reserch on reducing this noise, like quantum error correction, or looking into more advanced noise models for specific conditions of qubit temperatures, states and interactions could be a way to improve quantum simulations in future resreach.

# %% [markdown]
# ## How we divided up the work:
#
# - Hamiltonian and states: Lara
# - Classical Comparison: Kyran
# - Trotter method: Hugo and Kyran
# - Noise: Lara and Shae
# - IBM data: Tamara
# - Compiling code and final edits: Kyran, Lara, Tamara

# %% [markdown]
# ## References
#
# [1] Ayral, Thomas and Besserve, Pauline and Lacroix, Denis and Ruiz Guzman, Edgar Andres (2023). *Quantum computing with and for many-body physics*. The European Physical Journal A.
#
# [2] Furrer, A and Juranyi, F and Kr{\"a}mer, KW and Schneider, M and Str{\"a}ssle, Th (2011). *Single-ion versus two-ion anisotropy in magnetic compounds: A neutron scattering study*. Physical Review B—Condensed Matter and Materials Physics.
#
# [3] Stancil, Daniel D and Bakalov, Bojko N and Byrd, Gregory T (2025). *Connection between classical and quantum descriptions of spin waves using quantum circuits*. Physica Scripta.
#
# [4] Yi Qiao and Jian Wang and Junpeng Cao and Wen-Li Yang (2020). *Exact solution of an anisotropic J1 − J2 spin chain with antiperiodic boundary condition*. Nuclear Physics B.
#
# [5] Shaikh, Razin A and Wang, Quanlong and Yeung, Richie (2022). *How to sum and exponentiate Hamiltonians in ZXW calculus*. arXiv preprint arXiv:2212.04462.
#
# [6] Young, Dylan J and Song, Eric Yilun and Chu, Anjun and Barberena, Diego and Niu, Zhijing and Schafer, Vera M and Lewis-Swan, Robert J and Rey, Ana Maria and Thompson, James K (2024). *Time-resolved pairing gap spectroscopy in a quantum simulator of fermionic superfluidity inside an optical cavity*. arXiv preprint arXiv:2408.12640.
#
# [7] Ikeda, Tatsuhiko N and Abrar, Asir and Chuang, Isaac L and Sugiura, Sho (2023). *Minimum Trotterization formulas for a time-dependent Hamiltonian*. Quantum.
#
# [8] Javadi-Abhari, A and Martiel, S and Seif, A and Takita, M and Wei, KX (n.d.). *Big cats: entanglement in 120 qubits and beyond (2025)*. URL http://arxiv. org/abs/2510.09520. ArXiv.
#
# [9] {IBM Quantum} (2024). *Introduction to transpilation*
#
# [10] Bennakhi, Ahmad and Byrd, Gregory T and Franzon, Paul (2024). *Analyzing quantum circuit depth reduction with ancilla qubits in mcx gates*. 2024 IEEE International Conference on Quantum Computing and Engineering (QCE).
#
# [11] Serbyn, Maksym and Papić, Z. and Abanin, D. A. (2014). *Quantum quenches in the many-body localized phase*. Physical Review B.
#
# [12] Zhang, Robin (2017). *The baker-campbell-hausdorff formula*. Columbia University: New York, NY, USA.
#
# [13] Ramette, Joshua and Sinclair, Josiah and Breuckmann, Nikolas P and Vuleti{\'c}, Vladan (2024). *Fault-tolerant connection of error-corrected qubits with noisy links*. npj Quantum Information.
#
# [14] Kalai, Gil and Rinott, Yosef and Shoham, Tomer (2023). *Questions and Concerns About Google's Quantum Supremacy Claim*. arXiv preprint arXiv:2305.01064.
#
# [15] Gomes, Niladri and Mukherjee, Anirban and Zhang, Feng and Iadecola, Thomas and Wang, Cai-Zhuang and Ho, Kai-Ming and Orth, Peter P and Yao, Yong-Xin (2021). *Adaptive variational quantum imaginary time evolution approach for ground state preparation*. Advanced Quantum Technologies.
#
# [16] Ponce, Mario and Cope, Thomas and de Vega, Ines and Leib, Martin (2025). *Performance and scaling analysis of variational quantum simulation*. Quantum Science and Technology.
#
# [17] Javadi-Abhari, Ali and Treinish, Matthew and Krsulich, Kevin and Wood, Christopher J and Lishman, Jake and Gacon, Julien and Martiel, Simon and Nation, Paul D and Bishop, Lev S and Cross, Andrew W and others (2024). *Quantum computing with Qiskit*. arXiv preprint arXiv:2405.08810.
#
# [18] Dhand, Ish and Sanders, Barry C (2014). *Stability of the Trotter--Suzuki decomposition*. Journal of Physics A: Mathematical and Theoretical.
#
# [19] Kestner, J. P. and Das Sarma, S. (2011). *Proposed spin-qubit controlled-not gate robust against noisy coupling*. Physical Review A.
